# %% [markdown]
# # Open Library Search API Function
# Resource: https://openlibrary.org/dev/docs/api/search

# %%
import requests
import pandas as pd

# %%
class OpenLibraryClient:
    """
    A client to interact with the Open Library Search API and 
    return data as structured DataFrames or Lists.
    """
    
    BASE_URL = "https://openlibrary.org/search.json"

    def __init__(self):
        self.session = requests.Session()

    def search(self, query=None, title=None, author=None, limit=10, advanced=True):
        """
        Executes search and returns a Pandas DataFrame with advanced fields.
        """
        # Define fields to fetch - (Added missing quotes from your draft)
        fields = [
            "key", "title", "author_name", "author_key", "first_publish_year",
            "edition_count", "subject", "ratings_average", "ratings_count",
            "readinglog_count", "want_to_read_count", "currently_reading_count",
            "already_read_count", "language", "number_of_pages_median",
            "first_sentence", "cover_i", "publisher", "publish_date", 
            "person", "place", "time"
        ]
        
        params = {
            "limit": limit,
            "fields": ",".join(fields)
        }
        
        if query: params["q"] = query
        if title: params["title"] = title
        if author: params["author"] = author

        try:
            response = self.session.get(self.BASE_URL, params=params)
            response.raise_for_status()
            docs = response.json().get('docs', [])
            
            return self._process_to_dataframe(docs)
            
        except requests.exceptions.RequestException as e:
            print(f"API Error: {e}")
            return pd.DataFrame()

    def _process_to_dataframe(self, docs):
        """Internal helper to clean data into a table format."""
        rows = []
        for doc in docs:
            # Helper to join list fields into strings for easier NLP cleaning later
            def safe_join(field_name):
                val = doc.get(field_name, [])
                return ", ".join(val) if isinstance(val, list) else str(val)

            rows.append({
                "title": doc.get("title"),
                "author": safe_join("author_name"),
                "author_key": safe_join("author_key"),
                "year": doc.get("first_publish_year"),
                "editions": doc.get("edition_count", 0),
                "rating_avg": round(doc.get("ratings_average", 0), 2) if doc.get("ratings_average") else None,
                "rating_count": doc.get("ratings_count", 0),
                "want_to_read": doc.get("want_to_read_count", 0),
                "currently_reading": doc.get("currently_reading_count", 0),
                "already_read": doc.get("already_read_count", 0),
                "readinglog_count": doc.get("readinglog_count", 0),
                "pages": doc.get("number_of_pages_median"),
                "language": safe_join("language"),
                "publisher": safe_join("publisher"),
                "subjects": safe_join("subject"),
                "people": safe_join("person"),
                "places": safe_join("place"),
                "times": safe_join("time"),
                "first_sentence": doc.get("first_sentence"),
                "cover_url": f"https://covers.openlibrary.org/b/id/{doc.get('cover_i')}-L.jpg" if doc.get("cover_i") else None,
                "work_key": doc.get("key")
            })
            
        df = pd.DataFrame(rows)
        
        # --- FEATURE ENGINEERING FOR YOUR APP ---
        # Create a 'popularity_score' for your prediction model
        if not df.empty:
            df['popularity_score'] = df['rating_count'] + df['want_to_read'] + df['already_read']
            
        return df

# %%
# Create a default instance for easy importing
client = OpenLibraryClient()

# %%
# This looks at the file above and grabs the 'client' object
# from open_library_client import client 

# Now you can use it!
df = client.search(query="harry potter")
df
# Out:
#                                        title                          author  \
# 0  Harry Potter and the Order of the Phoenix                    J.K. Rowling
# 1   Harry Potter and the Philosopher's Stone                    J.K. Rowling
# 2       Harry Potter and the Deathly Hallows                    J.K. Rowling
# 3   Harry Potter and the Prisoner of Azkaban                    J.K. Rowling
# 4    Harry Potter and the Chamber of Secrets                    J.K. Rowling
# 5     Harry Potter and the Half-Blood Prince     J.K. Rowling, Mary GrandPré
# 6        Harry Potter and the Goblet of Fire                    J.K. Rowling
# 7                               Harry Potter  Warner Bros. Entertainment Inc
# 8                  Harry Potter (series) 1-7                    J.K. Rowling
# 9                               Harry Potter                   J. K. Rowling
#
#              author_key  year  editions  rating_avg  rating_count  \
# 0              OL23919A  2003       226        4.22           302
# 1              OL23919A  1997       357        4.24           941
# 2              OL23919A  2007       126        4.27           400
# 3              OL23919A  1999       263        4.25           608
# 4              OL23919A  1998       276        4.20           441
# 5  OL23919A, OL2703953A  2005       151        4.36           198
# 6              OL23919A  2000       231        4.27           327
# 7            OL7983102A  2007         1        3.88             8
# 8              OL23919A  1999        16        4.62            47
# 9              OL23919A  2001         2        3.22             9
#
#    want_to_read  currently_reading  already_read  ...  \
# 0          3364                285           632  ...
# 1         18313               1624          1515  ...
# 2          4565                336           717  ...
# 3          3929                287          1068  ...
# 4          4890                428           867  ...
# 5          2751                196           484  ...
# 6          3655                316           649  ...
# 7           217                 21            10  ...
# 8           479                 30            67  ...
# 9           197                  9             6  ...
#
#                                             language  \
# 0  eng, ben, heb, bul, tur, fre, ger, hun, dan, p...
# 1  urd, lat, hun, por, jpn, ltz, heb, ita, tha, b...
# 2  hun, por, jpn, heb, ita, ben, bul, spa, rus, h...
# 3  eng, ben, alb, heb, bul, tur, fre, ger, per, j...
# 4  spa, tha, chi, rus, vie, dan, ara, ger, pol, h...
# 5  hun, por, jpn, heb, ita, ben, bul, spa, rus, h...
# 6  eng, ben, alb, heb, bul, tur, fre, ger, per, d...
# 7                                                eng
# 8                                           eng, ger
# 9                                                eng
#
#                                            publisher  \
# 0  Aṅkura Prakāśanī, Seizansha, Gallimard, Listen...
# 1  Bloomsbury Publishing (IN), Salamandra, Emece ...
# 2  Salamandra, Editorial Presença, BLOOMSBURY, Ed...
# 3  Aṅkura Prakāśanī, Seizansha, Gallimard, Editur...
# 4  Arthur A. Levine Books: An Imprint of Scholast...
# 5  Salamandra, Lulu Press, Inc., Arthur A. Levine...
# 6  Aṅkura Prakāśanī, Seizansha, Gallimard, Listen...
# 7                        Warner Bros, Egmont UK Ltd.
# 8  Bloomsbury UK, Scholastic Inc., Bloomsbury Pub...
# 9                          Bloomsbury Publishing Plc
#
#                                             subjects  \
# 0  Children's Books/Ages 9-12 Fiction, Witches an...
# 1  series:Harry_Potter, Ghosts, Monsters, Vampire...
# 2  the Elder Wand, children's books, dementors, g...
# 3  Fantasy fiction, orphans, foster homes, fantas...
# 4  series:Harry_Potter, Fantasy fiction, school s...
# 5  orphans, foster homes, romans, magie, adolesce...
# 6  orphans, foster homes, Waisenkind, Intrige, Wi...
# 7  Motion pictures, Hogwarts School of Witchcraft...
# 8  New York Times bestseller, nyt:series_books=20...
# 9  Children's fiction, Potter, harry (fictitious ...
#
#                                               people  \
# 0  Harry Potter, Albus Dumbledore, Hagrid, Ron We...
# 1  Harry Potter, Ron Weasley, Hermione Granger, N...
# 2  Harry Potter, Gregorovitch, Greyback, Gellert ...
# 3  Harry Potter, Hermione Granger, Ron Weasley, S...
# 4  Harry Potter, Hermione Granger, Ron Weasley, A...
# 5  Harry Potter, Dumbledore, Lord Voldemort, Drac...
# 6  Harry Potter, Dumbledore, Hagrid, Ron Weasley,...
# 7                Harry Potter (Fictitious character)
# 8         Harry Potter, Hermione Granger, Ron Weasly
# 9
#
#                                               places          times  \
# 0  England, Hogwarts Schools of Witchcraft and Wi...
# 1  England, Hogwarts School of Witchcraft and Wiz...     Late 1990s
# 2  England, Scottland, Ireland, Wales, Hogwarts S...          1987-
# 3  England, Azkaban, Hogwarts School of Witchcraf...
# 4  England, London, Hogwarts School of Witchcraft...     Late 1990s
# 5  England, Hogwarts School of Witchcraft and Wiz...
# 6  England, Angleterre, Hogwarts School of Witchc...      2000-2009
# 7
# 8  Hogwarts School of Witchcraft and Wizardry, Br...  1990, Britain
# 9
#
#                                       first_sentence  \
# 0  [Il giorno più caldo dell’estate – almeno fino...
# 1  [O Sr. e a Sra. Dursley, da rua dos Alfeneiros...
# 2  [Les deux hommes surgirent de nulle part, à qu...
# 3  [Harry Potter era un ragazzo insolito sotto mo...
# 4  [Ce n’était pas la première fois qu’une disput...
# 5  [Il était près de minuit et le Premier Ministr...
# 6  [oopsy i farted, The villagers of Little Hangl...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                            cover_url            work_key  \
# 0  https://covers.openlibrary.org/b/id/10523466-L...     /works/OL82548W
# 1  https://covers.openlibrary.org/b/id/10521270-L...     /works/OL82563W
# 2  https://covers.openlibrary.org/b/id/10110415-L...     /works/OL82586W
# 3  https://covers.openlibrary.org/b/id/10580435-L...     /works/OL82536W
# 4  https://covers.openlibrary.org/b/id/8392798-L.jpg     /works/OL82537W
# 5  https://covers.openlibrary.org/b/id/10716273-L...     /works/OL82565W
# 6  https://covers.openlibrary.org/b/id/12059372-L...     /works/OL82560W
# 7  https://covers.openlibrary.org/b/id/10195373-L...  /works/OL20874116W
# 8  https://covers.openlibrary.org/b/id/8457523-L.jpg  /works/OL14981609W
# 9                                               None  /works/OL21385222W
#
#   popularity_score
# 0             4298
# 1            20769
# 2             5682
# 3             5605
# 4             6198
# 5             3433
# 6             4631
# 7              235
# 8              593
# 9              212
#
# [10 rows x 22 columns]

# %%
df.to_csv('Test_API_Sample.csv')
